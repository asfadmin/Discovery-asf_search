# %% [markdown]
# # asf_search - Geographic Search
# `asf_search` provides several search-oriented functions. One of these functions is `geo_search()`. This function accepts an area of interest in the form of a WKT (Well Known Text), as well as a variety of search parameters by which to refine your search results.
# ***
# ## Before You Start
# The steps outlined in this demonstration assume `asf_search` is available in your environment. For guidance on installing `asf_search`, [begin here](./1-Basic_Overview.ipynb#Before-You-Start).

# %% [markdown]
# ***
# ## Performing a Geographic Search
# [View this search in Vertex](https://search.asf.alaska.edu/#/?zoom=5.373&center=-153.186,53.964&polygon=POLYGON((-152.81%2058.49,-154.9%2057.49,-155.08%2056.3,-153.82%2056.34,-151.99%2057.3,-151.43%2058.19,-152.81%2058.49))&dataset=ALOS&start=2010-01-01T06:00:00Z&end=2010-02-02T05:59:59Z&resultsLoaded=true)
#
# To begin, we will need to craft a suitable WKT. ASF's [Vertex](https://search.asf.alaska.edu) can be helpful in this regard, as it allows you to draw on a map, or import a geospatial file such as a shapefile or geojson, after which a WKT string can be copied and used elsewhere.

# %%
import asf_search as asf

aoi = 'POLYGON((-152.81 58.49,-154.90 57.49,-155.08 56.30,-153.82 56.34,-151.99 57.30,-151.43 58.19,-152.81 58.49))'

# %% [markdown]
# Next, we will assemble any additional search parameters, such as platform, date range, and the type of product in which we are interested. All options to `geo_search()` can be specified using _kwargs_, which also allows them to be handled using a dictionary:

# %%
opts = {
    'platform': asf.PLATFORM.ALOS,
    'start': '2010-01-01',
    'end': '2010-02-01'
}

# %% [markdown]
# Once all the search parameters are ready, we can run the query and retrieve the results:

# %%
results = asf.geo_search(intersectsWith=aoi, **opts)

print(f'{len(results)} results found')

# %% [markdown]
# At this point, your search is complete and you can perform any of the usual workflows on your search results.

# %%
print(results)

# %% [markdown]
# ***
# ## Search Based on Scene's Footprint

# %% [markdown]
# As a secondary example, suppose you want to perform another geographic search to find results that overlap with one of your previous results. Using `shapely`, which is already installed by requirement of `asf_search` itself, we can quickly product a WKT based on a result and then perform a secondary search:

# %%
from shapely.geometry import shape

new_aoi = shape(results[0].geometry).wkt

refined_results = asf.geo_search(intersectsWith=new_aoi, **opts)

print(f'{len(refined_results)} results found')

# %% [markdown]
# ***
# ## Search Based on Scene's Centroid
# Alternately, suppose we would like to search for similar scenes that overlap another scene's centroid. `ASFProduct` provides a `centroid()` convenience function, which returns a `shapely.Point` object for this purpose:

# %%
centroid = results[0].centroid().wkt

centroid_results = asf.geo_search(intersectsWith=centroid, **opts)

print(f'{len(centroid_results)} results found')

# %% [markdown]
# ***
# ## Summary
# A complete, basic example of using `geo_search()`:

# %%
import asf_search as asf

print(
    asf.geo_search(
        intersectsWith='POLYGON((-152.81 58.49,-154.90 57.49,-155.08 56.30,-153.82 56.34,-151.99 57.30,-151.43 58.19,-152.81 58.49))',
        platform=asf.PLATFORM.ALOS,
        start='2010-01-01',
        end='2010-02-01'))
# Out:
# {
#   "features": [
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.697,
#               58.005
#             ],
#             [
#               -151.873,
#               58.504
#             ],
#             [
#               -150.762,
#               58.611
#             ],
#             [
#               -150.601,
#               58.112
#             ],
#             [
#               -151.697,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP214031160.jpg"
#         ],
#         "bytes": "320779054",
#         "faradayRotation": "0.964755",
#         "fileID": "ALPSRP214031160-L1.0",
#         "fileName": "ALPSRP214031160-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1462090",
#         "md5sum": "11953c266d1e821f05f5a68fcc8d244a",
#         "offNadirAngle": "34.3",
#         "orbit": "21403",
#         "pathNumber": "266",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-09-28T23:40:52Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP214031160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-30T08:17:08Z",
#         "stopTime": "2010-01-30T08:17:16Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP214031160-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.697,
#               58.005
#             ],
#             [
#               -151.873,
#               58.504
#             ],
#             [
#               -150.762,
#               58.611
#             ],
#             [
#               -150.601,
#               58.112
#             ],
#             [
#               -151.697,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP214031160.jpg"
#         ],
#         "bytes": "171076525",
#         "faradayRotation": "0.964755",
#         "fileID": "ALPSRP214031160-L1.5",
#         "fileName": "ALPSRP214031160-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1462090",
#         "md5sum": "05a309988598db24d85709ae9912e36f",
#         "offNadirAngle": "34.3",
#         "orbit": "21403",
#         "pathNumber": "266",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-09-28T23:48:10Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP214031160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-30T08:17:08Z",
#         "stopTime": "2010-01-30T08:17:16Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP214031160-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.524,
#               57.516
#             ],
#             [
#               -151.696,
#               58.015
#             ],
#             [
#               -150.601,
#               58.121
#             ],
#             [
#               -150.442,
#               57.622
#             ],
#             [
#               -151.524,
#               57.516
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP214031150.jpg"
#         ],
#         "bytes": "312816062",
#         "faradayRotation": "0.990203",
#         "fileID": "ALPSRP214031150-L1.0",
#         "fileName": "ALPSRP214031150-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1454271",
#         "md5sum": "f5506b94f4098310a1465ffb57cbed2c",
#         "offNadirAngle": "34.3",
#         "orbit": "21403",
#         "pathNumber": "266",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-09-28T23:39:51Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP214031150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-30T08:17:00Z",
#         "stopTime": "2010-01-30T08:17:08Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP214031150-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.524,
#               57.516
#             ],
#             [
#               -151.696,
#               58.015
#             ],
#             [
#               -150.601,
#               58.121
#             ],
#             [
#               -150.442,
#               57.622
#             ],
#             [
#               -151.524,
#               57.516
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP214031150.jpg"
#         ],
#         "bytes": "170036978",
#         "faradayRotation": "0.990203",
#         "fileID": "ALPSRP214031150-L1.5",
#         "fileName": "ALPSRP214031150-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1454271",
#         "md5sum": "0d04d8ff128bdb5d99ee32cd9a346fee",
#         "offNadirAngle": "34.3",
#         "orbit": "21403",
#         "pathNumber": "266",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-09-28T23:47:17Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP214031150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-30T08:17:00Z",
#         "stopTime": "2010-01-30T08:17:08Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP214031150-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.77,
#               57.367
#             ],
#             [
#               -155.947,
#               57.868
#             ],
#             [
#               -154.849,
#               57.953
#             ],
#             [
#               -154.688,
#               57.451
#             ],
#             [
#               -155.77,
#               57.367
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741150.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1150.jpg"
#         ],
#         "bytes": "9535871.0",
#         "faradayRotation": "0.991815",
#         "fileID": "ALPSRP213741150-KMZ",
#         "fileName": "AP_21374_FBS_F1150.kmz",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1496767",
#         "md5sum": "3525af04bce12a140c63377516052d61",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:26:53Z",
#         "processingLevel": "KMZ",
#         "sceneName": "ALPSRP213741150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:10Z",
#         "stopTime": "2010-01-28T08:34:19Z",
#         "url": "https://datapool.asf.alaska.edu/KMZ/A3/AP_21374_FBS_F1150.kmz"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.77,
#               57.367
#             ],
#             [
#               -155.947,
#               57.868
#             ],
#             [
#               -154.849,
#               57.953
#             ],
#             [
#               -154.688,
#               57.451
#             ],
#             [
#               -155.77,
#               57.367
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741150.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1150.jpg"
#         ],
#         "bytes": "423555942",
#         "faradayRotation": "0.991815",
#         "fileID": "ALPSRP213741150-L1.0",
#         "fileName": "ALPSRP213741150-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1496767",
#         "md5sum": "785034fb43c9c34697a08886c197e17f",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-17T03:03:44Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP213741150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:10Z",
#         "stopTime": "2010-01-28T08:34:19Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP213741150-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.77,
#               57.367
#             ],
#             [
#               -155.947,
#               57.868
#             ],
#             [
#               -154.849,
#               57.953
#             ],
#             [
#               -154.688,
#               57.451
#             ],
#             [
#               -155.77,
#               57.367
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741150.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1150.jpg"
#         ],
#         "bytes": "180785891",
#         "faradayRotation": "0.991815",
#         "fileID": "ALPSRP213741150-L1.5",
#         "fileName": "ALPSRP213741150-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1496767",
#         "md5sum": "7ed35b97086f284cc9b7b83afb96e30d",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-17T03:12:29Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP213741150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:10Z",
#         "stopTime": "2010-01-28T08:34:19Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP213741150-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.947,
#               57.868
#             ],
#             [
#               -154.849,
#               57.953
#             ],
#             [
#               -154.688,
#               57.451
#             ],
#             [
#               -155.77,
#               57.367
#             ],
#             [
#               -155.947,
#               57.868
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741150.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1150.jpg"
#         ],
#         "bytes": "221063289.0",
#         "faradayRotation": "0.991815",
#         "fileID": "ALPSRP213741150-RTC_HI_RES",
#         "fileName": "AP_21374_FBS_F1150_RT1.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": "ALPSRP213741150",
#         "insarStackId": "1496767",
#         "md5sum": "f1c600d4b534cffdf19b27ce33f776bd",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2018-06-03T13:26:46Z",
#         "processingLevel": "RTC_HI_RES",
#         "sceneName": "ALPSRP213741150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:10Z",
#         "stopTime": "2010-01-28T08:34:19Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_HI_RES/A3/AP_21374_FBS_F1150_RT1.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.947,
#               57.868
#             ],
#             [
#               -154.849,
#               57.953
#             ],
#             [
#               -154.688,
#               57.451
#             ],
#             [
#               -155.77,
#               57.367
#             ],
#             [
#               -155.947,
#               57.868
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741150.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1150.jpg"
#         ],
#         "bytes": "47381482.0",
#         "faradayRotation": "0.991815",
#         "fileID": "ALPSRP213741150-RTC_LOW_RES",
#         "fileName": "AP_21374_FBS_F1150_RT2.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": "ALPSRP213741150",
#         "insarStackId": "1496767",
#         "md5sum": "24c414b9cbf0480bd21e4fe9a9d6d0ba",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2018-06-03T13:26:26Z",
#         "processingLevel": "RTC_LOW_RES",
#         "sceneName": "ALPSRP213741150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:10Z",
#         "stopTime": "2010-01-28T08:34:19Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_LOW_RES/A3/AP_21374_FBS_F1150_RT2.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.596,
#               56.875
#             ],
#             [
#               -155.774,
#               57.376
#             ],
#             [
#               -154.691,
#               57.461
#             ],
#             [
#               -154.528,
#               56.959
#             ],
#             [
#               -155.596,
#               56.875
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741140.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1140.jpg"
#         ],
#         "bytes": "9408788.0",
#         "faradayRotation": "1.013735",
#         "fileID": "ALPSRP213741140-KMZ",
#         "fileName": "AP_21374_FBS_F1140.kmz",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1397110",
#         "md5sum": "acc37aa71a938ef4a30da4b58026f756",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:25:52Z",
#         "processingLevel": "KMZ",
#         "sceneName": "ALPSRP213741140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:02Z",
#         "stopTime": "2010-01-28T08:34:10Z",
#         "url": "https://datapool.asf.alaska.edu/KMZ/A3/AP_21374_FBS_F1140.kmz"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.596,
#               56.875
#             ],
#             [
#               -155.774,
#               57.376
#             ],
#             [
#               -154.691,
#               57.461
#             ],
#             [
#               -154.528,
#               56.959
#             ],
#             [
#               -155.596,
#               56.875
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741140.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1140.jpg"
#         ],
#         "bytes": "385749220",
#         "faradayRotation": "1.013735",
#         "fileID": "ALPSRP213741140-L1.0",
#         "fileName": "ALPSRP213741140-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1397110",
#         "md5sum": "c21585350cc7ddfb4bcb964e927227dd",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-17T03:03:06Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP213741140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:02Z",
#         "stopTime": "2010-01-28T08:34:10Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP213741140-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.596,
#               56.875
#             ],
#             [
#               -155.774,
#               57.376
#             ],
#             [
#               -154.691,
#               57.461
#             ],
#             [
#               -154.528,
#               56.959
#             ],
#             [
#               -155.596,
#               56.875
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741140.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1140.jpg"
#         ],
#         "bytes": "177961100",
#         "faradayRotation": "1.013735",
#         "fileID": "ALPSRP213741140-L1.5",
#         "fileName": "ALPSRP213741140-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1397110",
#         "md5sum": "9c0fccc3b1a81889a01eb5d855a2d56b",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-17T03:11:54Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP213741140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:02Z",
#         "stopTime": "2010-01-28T08:34:10Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP213741140-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.596,
#               56.875
#             ],
#             [
#               -155.774,
#               57.376
#             ],
#             [
#               -154.691,
#               57.461
#             ],
#             [
#               -154.528,
#               56.959
#             ],
#             [
#               -155.596,
#               56.875
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741140.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1140.jpg"
#         ],
#         "bytes": "199643584.0",
#         "faradayRotation": "1.013735",
#         "fileID": "ALPSRP213741140-RTC_HI_RES",
#         "fileName": "AP_21374_FBS_F1140_RT1.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1397110",
#         "md5sum": "bb4fa3b71a042d696f0c1e8a332fe0b4",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:26:19Z",
#         "processingLevel": "RTC_HI_RES",
#         "sceneName": "ALPSRP213741140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:02Z",
#         "stopTime": "2010-01-28T08:34:10Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_HI_RES/A3/AP_21374_FBS_F1140_RT1.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.596,
#               56.875
#             ],
#             [
#               -155.774,
#               57.376
#             ],
#             [
#               -154.691,
#               57.461
#             ],
#             [
#               -154.528,
#               56.959
#             ],
#             [
#               -155.596,
#               56.875
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741140.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1140.jpg"
#         ],
#         "bytes": "44183968.0",
#         "faradayRotation": "1.013735",
#         "fileID": "ALPSRP213741140-RTC_LOW_RES",
#         "fileName": "AP_21374_FBS_F1140_RT2.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1397110",
#         "md5sum": "6b97a82760d42d1463a1818c58f3d91e",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:25:52Z",
#         "processingLevel": "RTC_LOW_RES",
#         "sceneName": "ALPSRP213741140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:34:02Z",
#         "stopTime": "2010-01-28T08:34:10Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_LOW_RES/A3/AP_21374_FBS_F1140_RT2.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.429,
#               56.383
#             ],
#             [
#               -155.6,
#               56.884
#             ],
#             [
#               -154.531,
#               56.968
#             ],
#             [
#               -154.375,
#               56.466
#             ],
#             [
#               -155.429,
#               56.383
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741130.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1130.jpg"
#         ],
#         "bytes": "8885844.0",
#         "faradayRotation": "1.040475",
#         "fileID": "ALPSRP213741130-KMZ",
#         "fileName": "AP_21374_FBS_F1130.kmz",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1130",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1461503",
#         "md5sum": "723bbade4d757129bb1f132946db261e",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:25:47Z",
#         "processingLevel": "KMZ",
#         "sceneName": "ALPSRP213741130",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:33:54Z",
#         "stopTime": "2010-01-28T08:34:02Z",
#         "url": "https://datapool.asf.alaska.edu/KMZ/A3/AP_21374_FBS_F1130.kmz"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.429,
#               56.383
#             ],
#             [
#               -155.6,
#               56.884
#             ],
#             [
#               -154.531,
#               56.968
#             ],
#             [
#               -154.375,
#               56.466
#             ],
#             [
#               -155.429,
#               56.383
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741130.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1130.jpg"
#         ],
#         "bytes": "364585501",
#         "faradayRotation": "1.040475",
#         "fileID": "ALPSRP213741130-L1.0",
#         "fileName": "ALPSRP213741130-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1130",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1461503",
#         "md5sum": "33583d45bb416a470029f7701a4aa7cc",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-17T03:03:15Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP213741130",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:33:54Z",
#         "stopTime": "2010-01-28T08:34:02Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP213741130-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.429,
#               56.383
#             ],
#             [
#               -155.6,
#               56.884
#             ],
#             [
#               -154.531,
#               56.968
#             ],
#             [
#               -154.375,
#               56.466
#             ],
#             [
#               -155.429,
#               56.383
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741130.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1130.jpg"
#         ],
#         "bytes": "172917968",
#         "faradayRotation": "1.040475",
#         "fileID": "ALPSRP213741130-L1.5",
#         "fileName": "ALPSRP213741130-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1130",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1461503",
#         "md5sum": "cd453f04081e6181665da707997ae88d",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-17T03:12:02Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP213741130",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:33:54Z",
#         "stopTime": "2010-01-28T08:34:02Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP213741130-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.429,
#               56.383
#             ],
#             [
#               -155.6,
#               56.884
#             ],
#             [
#               -154.531,
#               56.968
#             ],
#             [
#               -154.375,
#               56.466
#             ],
#             [
#               -155.429,
#               56.383
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741130.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1130.jpg"
#         ],
#         "bytes": "196186191.0",
#         "faradayRotation": "1.040475",
#         "fileID": "ALPSRP213741130-RTC_HI_RES",
#         "fileName": "AP_21374_FBS_F1130_RT1.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1130",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1461503",
#         "md5sum": "687ff2c617219e8c81fdd818b961e930",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:26:15Z",
#         "processingLevel": "RTC_HI_RES",
#         "sceneName": "ALPSRP213741130",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:33:54Z",
#         "stopTime": "2010-01-28T08:34:02Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_HI_RES/A3/AP_21374_FBS_F1130_RT1.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -155.429,
#               56.383
#             ],
#             [
#               -155.6,
#               56.884
#             ],
#             [
#               -154.531,
#               56.968
#             ],
#             [
#               -154.375,
#               56.466
#             ],
#             [
#               -155.429,
#               56.383
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213741130.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21374_FBS_F1130.jpg"
#         ],
#         "bytes": "43038180.0",
#         "faradayRotation": "1.040475",
#         "fileID": "ALPSRP213741130-RTC_LOW_RES",
#         "fileName": "AP_21374_FBS_F1130_RT2.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1130",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1461503",
#         "md5sum": "850c1031dc572c25dbab0b301f2fefa6",
#         "offNadirAngle": "34.3",
#         "orbit": "21374",
#         "pathNumber": "274",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T11:25:47Z",
#         "processingLevel": "RTC_LOW_RES",
#         "sceneName": "ALPSRP213741130",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-28T08:33:54Z",
#         "stopTime": "2010-01-28T08:34:02Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_LOW_RES/A3/AP_21374_FBS_F1130_RT2.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -153.502,
#               56.293
#             ],
#             [
#               -154.786,
#               53.252
#             ],
#             [
#               -160.055,
#               53.754
#             ],
#             [
#               -159.179,
#               56.823
#             ],
#             [
#               -153.502,
#               56.293
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS213672500.jpg"
#         ],
#         "bytes": "469397597",
#         "faradayRotation": null,
#         "fileID": "ALPSRS213672500-L1.0",
#         "fileName": "ALPSRS213672500-L1.0.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2500",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "034d4d4b34fc2ea81eb2205ff6f8bea6",
#         "offNadirAngle": "27.1",
#         "orbit": "21367",
#         "pathNumber": "623",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2014-07-09T10:19:53Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRS213672500",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-27T21:21:16Z",
#         "stopTime": "2010-01-27T21:21:41Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRS213672500-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -153.502,
#               56.293
#             ],
#             [
#               -154.786,
#               53.252
#             ],
#             [
#               -160.055,
#               53.754
#             ],
#             [
#               -159.179,
#               56.823
#             ],
#             [
#               -153.502,
#               56.293
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS213672500.jpg"
#         ],
#         "bytes": "25770501",
#         "faradayRotation": null,
#         "fileID": "ALPSRS213672500-L1.5",
#         "fileName": "ALPSRS213672500-L1.5.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2500",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "9b5306bee12bcd12c819719e33870248",
#         "offNadirAngle": "27.1",
#         "orbit": "21367",
#         "pathNumber": "623",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2014-07-09T10:31:34Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRS213672500",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-27T21:21:16Z",
#         "stopTime": "2010-01-27T21:21:41Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRS213672500-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.347,
#               58.728
#             ],
#             [
#               -153.766,
#               55.696
#             ],
#             [
#               -159.358,
#               56.22
#             ],
#             [
#               -158.413,
#               59.286
#             ],
#             [
#               -152.347,
#               58.728
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS213672450.jpg"
#         ],
#         "bytes": "538450706",
#         "faradayRotation": null,
#         "fileID": "ALPSRS213672450-L1.0",
#         "fileName": "ALPSRS213672450-L1.0.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2450",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "2a7fefe8357be8a6324de5ecc4690ff4",
#         "offNadirAngle": "27.1",
#         "orbit": "21367",
#         "pathNumber": "623",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2014-07-09T10:18:36Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRS213672450",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-27T21:20:35Z",
#         "stopTime": "2010-01-27T21:21:00Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRS213672450-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.347,
#               58.728
#             ],
#             [
#               -153.766,
#               55.696
#             ],
#             [
#               -159.358,
#               56.22
#             ],
#             [
#               -158.413,
#               59.286
#             ],
#             [
#               -152.347,
#               58.728
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS213672450.jpg"
#         ],
#         "bytes": "28979705",
#         "faradayRotation": null,
#         "fileID": "ALPSRS213672450-L1.5",
#         "fileName": "ALPSRS213672450-L1.5.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2450",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "8db3635b3aa2d09184c680f93b930510",
#         "offNadirAngle": "27.1",
#         "orbit": "21367",
#         "pathNumber": "623",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2014-07-09T10:31:55Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRS213672450",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-27T21:20:35Z",
#         "stopTime": "2010-01-27T21:21:00Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRS213672450-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.044,
#               61.153
#             ],
#             [
#               -152.641,
#               58.133
#             ],
#             [
#               -158.606,
#               58.683
#             ],
#             [
#               -157.569,
#               61.746
#             ],
#             [
#               -151.044,
#               61.153
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS213672400.jpg"
#         ],
#         "bytes": "493289371",
#         "faradayRotation": null,
#         "fileID": "ALPSRS213672400-L1.0",
#         "fileName": "ALPSRS213672400-L1.0.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2400",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "ea07e817290761275636e4b5c9cefe42",
#         "offNadirAngle": "27.1",
#         "orbit": "21367",
#         "pathNumber": "623",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2014-07-09T10:17:55Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRS213672400",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-27T21:19:54Z",
#         "stopTime": "2010-01-27T21:20:19Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRS213672400-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.044,
#               61.153
#             ],
#             [
#               -152.641,
#               58.133
#             ],
#             [
#               -158.606,
#               58.683
#             ],
#             [
#               -157.569,
#               61.746
#             ],
#             [
#               -151.044,
#               61.153
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS213672400.jpg"
#         ],
#         "bytes": "26289488",
#         "faradayRotation": null,
#         "fileID": "ALPSRS213672400-L1.5",
#         "fileName": "ALPSRS213672400-L1.5.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2400",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "a253d0732ea1bf902b46b9a70bfe1334",
#         "offNadirAngle": "27.1",
#         "orbit": "21367",
#         "pathNumber": "623",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2014-07-09T10:29:52Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRS213672400",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-27T21:19:54Z",
#         "stopTime": "2010-01-27T21:20:19Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRS213672400-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -154.383,
#               58.005
#             ],
#             [
#               -154.559,
#               58.505
#             ],
#             [
#               -153.448,
#               58.612
#             ],
#             [
#               -153.288,
#               58.112
#             ],
#             [
#               -154.383,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213011160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21301_FBS_F1160.jpg"
#         ],
#         "bytes": "7665761.0",
#         "faradayRotation": "1.457187",
#         "fileID": "ALPSRP213011160-KMZ",
#         "fileName": "AP_21301_FBS_F1160.kmz",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1477341",
#         "md5sum": "e9b862979ac8a434eb8adb56615b74e7",
#         "offNadirAngle": "34.3",
#         "orbit": "21301",
#         "pathNumber": "271",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T08:33:13Z",
#         "processingLevel": "KMZ",
#         "sceneName": "ALPSRP213011160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-23T08:27:54Z",
#         "stopTime": "2010-01-23T08:28:02Z",
#         "url": "https://datapool.asf.alaska.edu/KMZ/A3/AP_21301_FBS_F1160.kmz"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -154.383,
#               58.005
#             ],
#             [
#               -154.559,
#               58.505
#             ],
#             [
#               -153.448,
#               58.612
#             ],
#             [
#               -153.288,
#               58.112
#             ],
#             [
#               -154.383,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213011160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21301_FBS_F1160.jpg"
#         ],
#         "bytes": "408790036",
#         "faradayRotation": "1.457187",
#         "fileID": "ALPSRP213011160-L1.0",
#         "fileName": "ALPSRP213011160-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1477341",
#         "md5sum": "eb854a065fd49b31dfdf5397c62177b8",
#         "offNadirAngle": "34.3",
#         "orbit": "21301",
#         "pathNumber": "271",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2012-10-01T00:00:00Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP213011160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-23T08:27:54Z",
#         "stopTime": "2010-01-23T08:28:02Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP213011160-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -154.383,
#               58.005
#             ],
#             [
#               -154.559,
#               58.505
#             ],
#             [
#               -153.448,
#               58.612
#             ],
#             [
#               -153.288,
#               58.112
#             ],
#             [
#               -154.383,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213011160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21301_FBS_F1160.jpg"
#         ],
#         "bytes": "180564786",
#         "faradayRotation": "1.457187",
#         "fileID": "ALPSRP213011160-L1.5",
#         "fileName": "ALPSRP213011160-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1477341",
#         "md5sum": "8b9b6058da3822f142c0506635c0329b",
#         "offNadirAngle": "34.3",
#         "orbit": "21301",
#         "pathNumber": "271",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2012-10-01T00:00:00Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP213011160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-23T08:27:54Z",
#         "stopTime": "2010-01-23T08:28:02Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP213011160-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -154.383,
#               58.005
#             ],
#             [
#               -154.559,
#               58.505
#             ],
#             [
#               -153.448,
#               58.612
#             ],
#             [
#               -153.288,
#               58.112
#             ],
#             [
#               -154.383,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213011160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_21301_FBS_F1160.jpg"
#         ],
#         "bytes": "218105743.0",
#         "faradayRotation": "1.457187",
#         "fileID": "ALPSRP213011160-RTC_HI_RES",
#         "fileName": "AP_21301_FBS_F1160_RT1.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1477341",
#         "md5sum": "217b20b20ac1d0d99363940c774bcc9d",
#         "offNadirAngle": "34.3",
#         "orbit": "21301",
#         "pathNumber": "271",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-30T08:33:50Z",
#         "processingLevel": "RTC_HI_RES",
#         "sceneName": "ALPSRP213011160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-23T08:27:54Z",
#         "stopTime": "2010-01-23T08:28:02Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_HI_RES/A3/AP_21301_FBS_F1160_RT1.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -154.383,
#               58.005
#             ],
#             [
#               -154.559,
#               58.505
#             ],
#             [
#               -153.448,
#               58.612
#             ],
#             [
#               -153.288,
#               58.112
#             ],
#             [
#               -154.383,
#               58.005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP213011160.jpg",
# ...
#               -156.41,
#               58.85
#             ],
#             [
#               -155.371,
#               61.896
#             ],
#             [
#               -148.867,
#               61.202
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS210462400.jpg"
#         ],
#         "bytes": "25243464",
#         "faradayRotation": null,
#         "fileID": "ALPSRS210462400-L1.5",
#         "fileName": "ALPSRS210462400-L1.5.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": "2400",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "0",
#         "md5sum": "aa42731b2df11680e9e9fe17729bfd94",
#         "offNadirAngle": null,
#         "orbit": "21046",
#         "pathNumber": "619",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH 5scan",
#         "processingDate": "2011-06-07T17:00:38Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRS210462400",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-05T21:11:23Z",
#         "stopTime": "2010-01-05T21:11:48Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRS210462400-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.241,
#               58.003
#             ],
#             [
#               -152.422,
#               58.502
#             ],
#             [
#               -151.311,
#               58.609
#             ],
#             [
#               -151.146,
#               58.11
#             ],
#             [
#               -152.241,
#               58.003
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_20980_FBS_F1160.jpg"
#         ],
#         "bytes": "6161650.0",
#         "faradayRotation": "1.252511",
#         "fileID": "ALPSRP209801160-KMZ",
#         "fileName": "AP_20980_FBS_F1160.kmz",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1438670",
#         "md5sum": "7e237105ec836470f63fd37486edb966",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-29T19:14:33Z",
#         "processingLevel": "KMZ",
#         "sceneName": "ALPSRP209801160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:22Z",
#         "stopTime": "2010-01-01T08:19:30Z",
#         "url": "https://datapool.asf.alaska.edu/KMZ/A3/AP_20980_FBS_F1160.kmz"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.241,
#               58.003
#             ],
#             [
#               -152.422,
#               58.502
#             ],
#             [
#               -151.311,
#               58.609
#             ],
#             [
#               -151.146,
#               58.11
#             ],
#             [
#               -152.241,
#               58.003
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_20980_FBS_F1160.jpg"
#         ],
#         "bytes": "368348494",
#         "faradayRotation": "1.252511",
#         "fileID": "ALPSRP209801160-L1.0",
#         "fileName": "ALPSRP209801160-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1438670",
#         "md5sum": "9e8a0526c6f2af52f2b61f61f9d39149",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-15T03:05:14Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP209801160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:22Z",
#         "stopTime": "2010-01-01T08:19:30Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP209801160-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.241,
#               58.003
#             ],
#             [
#               -152.422,
#               58.502
#             ],
#             [
#               -151.311,
#               58.609
#             ],
#             [
#               -151.146,
#               58.11
#             ],
#             [
#               -152.241,
#               58.003
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_20980_FBS_F1160.jpg"
#         ],
#         "bytes": "177752970",
#         "faradayRotation": "1.252511",
#         "fileID": "ALPSRP209801160-L1.5",
#         "fileName": "ALPSRP209801160-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1438670",
#         "md5sum": "29dbb00886c84ded9cfe3e1ebba701db",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-15T03:12:48Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP209801160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:22Z",
#         "stopTime": "2010-01-01T08:19:30Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP209801160-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.241,
#               58.003
#             ],
#             [
#               -152.422,
#               58.502
#             ],
#             [
#               -151.311,
#               58.609
#             ],
#             [
#               -151.146,
#               58.11
#             ],
#             [
#               -152.241,
#               58.003
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_20980_FBS_F1160.jpg"
#         ],
#         "bytes": "208534684.0",
#         "faradayRotation": "1.252511",
#         "fileID": "ALPSRP209801160-RTC_HI_RES",
#         "fileName": "AP_20980_FBS_F1160_RT1.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1438670",
#         "md5sum": "eee39db9cee8dbe3f4d6c01bc324a4d5",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-29T19:15:02Z",
#         "processingLevel": "RTC_HI_RES",
#         "sceneName": "ALPSRP209801160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:22Z",
#         "stopTime": "2010-01-01T08:19:30Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_HI_RES/A3/AP_20980_FBS_F1160_RT1.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.241,
#               58.003
#             ],
#             [
#               -152.422,
#               58.502
#             ],
#             [
#               -151.311,
#               58.609
#             ],
#             [
#               -151.146,
#               58.11
#             ],
#             [
#               -152.241,
#               58.003
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801160.jpg",
#           "https://datapool.asf.alaska.edu/BROWSE/A3/AP_20980_FBS_F1160.jpg"
#         ],
#         "bytes": "42943165.0",
#         "faradayRotation": "1.252511",
#         "fileID": "ALPSRP209801160-RTC_LOW_RES",
#         "fileName": "AP_20980_FBS_F1160_RT2.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1160",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1438670",
#         "md5sum": "4d5bc69efe03f58a751043bf7338df97",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2015-03-29T19:14:32Z",
#         "processingLevel": "RTC_LOW_RES",
#         "sceneName": "ALPSRP209801160",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:22Z",
#         "stopTime": "2010-01-01T08:19:30Z",
#         "url": "https://datapool.asf.alaska.edu/RTC_LOW_RES/A3/AP_20980_FBS_F1160_RT2.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.068,
#               57.514
#             ],
#             [
#               -152.245,
#               58.013
#             ],
#             [
#               -151.149,
#               58.119
#             ],
#             [
#               -150.987,
#               57.62
#             ],
#             [
#               -152.068,
#               57.514
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801150.jpg"
#         ],
#         "bytes": "343586630",
#         "faradayRotation": "1.296698",
#         "fileID": "ALPSRP209801150-L1.0",
#         "fileName": "ALPSRP209801150-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1462910",
#         "md5sum": "e9d1dd01051fcd7828753973e93b2bc9",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-15T03:05:23Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP209801150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:14Z",
#         "stopTime": "2010-01-01T08:19:22Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP209801150-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -152.068,
#               57.514
#             ],
#             [
#               -152.245,
#               58.013
#             ],
#             [
#               -151.149,
#               58.119
#             ],
#             [
#               -150.987,
#               57.62
#             ],
#             [
#               -152.068,
#               57.514
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801150.jpg"
#         ],
#         "bytes": "171078413",
#         "faradayRotation": "1.296698",
#         "fileID": "ALPSRP209801150-L1.5",
#         "fileName": "ALPSRP209801150-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1150",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1462910",
#         "md5sum": "e6593962c3a54435ee1078ce7b903be8",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-15T03:12:42Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP209801150",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:14Z",
#         "stopTime": "2010-01-01T08:19:22Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP209801150-L1.5.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.893,
#               57.024
#             ],
#             [
#               -152.071,
#               57.523
#             ],
#             [
#               -150.99,
#               57.629
#             ],
#             [
#               -150.826,
#               57.13
#             ],
#             [
#               -151.893,
#               57.024
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801140.jpg"
#         ],
#         "bytes": "323324793",
#         "faradayRotation": "1.344072",
#         "fileID": "ALPSRP209801140-L1.0",
#         "fileName": "ALPSRP209801140-L1.0.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1464511",
#         "md5sum": "0b6dab91ae875a94f31f7dbcf6798298",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-15T03:04:45Z",
#         "processingLevel": "L1.0",
#         "sceneName": "ALPSRP209801140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:06Z",
#         "stopTime": "2010-01-01T08:19:14Z",
#         "url": "https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP209801140-L1.0.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -151.893,
#               57.024
#             ],
#             [
#               -152.071,
#               57.523
#             ],
#             [
#               -150.99,
#               57.629
#             ],
#             [
#               -150.826,
#               57.13
#             ],
#             [
#               -151.893,
#               57.024
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "FBS",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRP209801140.jpg"
#         ],
#         "bytes": "170890057",
#         "faradayRotation": "1.344072",
#         "fileID": "ALPSRP209801140-L1.5",
#         "fileName": "ALPSRP209801140-L1.5.zip",
#         "flightDirection": "ASCENDING",
#         "frameNumber": "1140",
#         "granuleType": "ALOS_PALSAR_SCENE",
#         "groupID": null,
#         "insarStackId": "1464511",
#         "md5sum": "32cc42ded5fedd7f583836373fbdd7e5",
#         "offNadirAngle": "34.3",
#         "orbit": "20980",
#         "pathNumber": "267",
#         "platform": "ALOS",
#         "pointingAngle": null,
#         "polarization": "HH",
#         "processingDate": "2013-03-15T03:12:12Z",
#         "processingLevel": "L1.5",
#         "sceneName": "ALPSRP209801140",
#         "sensor": "PALSAR",
#         "startTime": "2010-01-01T08:19:06Z",
#         "stopTime": "2010-01-01T08:19:14Z",
#         "url": "https://datapool.asf.alaska.edu/L1.5/A3/ALPSRP209801140-L1.5.zip"
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Next: [Granule Searches](./3-Granule_Search.ipynb)
